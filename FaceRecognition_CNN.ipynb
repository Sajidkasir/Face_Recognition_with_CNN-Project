# %% [markdown]
# <a href="https://colab.research.google.com/github/Sajidkasir/Face_Recognition_with_CNN-Project/blob/main/FaceRecognition_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
!7za -y x "/content/drive/MyDrive/DSAI PROJECT/data/image"
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 folder, 8 files, 8113576419 bytes (7738 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/DSAI PROJECT/data/image/origin.7z.001
# --
# Path = /content/drive/MyDrive/DSAI PROJECT/data/image/origin.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 8
# Total Physical Size = 8113576419
# ----
# Path = origin.7z
# Size = 8113576419
# --
# Path = origin.7z
# Type = 7z
# Physical Size = 8113576419
# Headers Size = 863607
# Method = LZMA:25
# Solid = +
# Blocks = 2
#
#   1% 1732 - origin/amazed_american_840.jpg
# Archives with Errors: 1
#
#
#
# Break signaled

# %%
# !cp -r ./origin "/content/drive/MyDrive/DSAI PROJECT"
# Out:
# ^C

# %%
import tensorflow as tf
#import tensorflow to provide different libary to building
# and training different ML models and Neural Network.
import cv2
# cv2 stand for Opencv(open source computer vision) this is the libray to interact
# with pictures and videos processing
from os.path import split
# os Stand for Operating system. it interact with system file such as deleting,
# and modification and check directories
import matplotlib.pyplot as plt
# this library is use to construct graphs, plots and charts
import numpy as np
# numpy is a numerical library consist of arrays and mathematical functions
import pandas as pd
import matplotlib.image as mpimg

# %%
label_file_name=r"/content/drive/MyDrive/DSAI PROJECT/data/label/label.lst"
image_file_name=r"/content/drive/MyDrive/DSAI PROJECT/origin"

# %%
df_info = pd.read_csv(label_file_name, sep=" ", header=None)

col_names = "image_name face_id_in_image face_box_top face_box_left face_box_right face_box_bottom face_box_confidence expression_label".split()

df_info.columns = col_names
data_path = "/content/drive/MyDrive/Colab Notebooks/origin"

df_info.head()
# Out:
#             image_name  face_id_in_image  face_box_top  face_box_left  \
# 0  angry_actor_104.jpg                 0            28            113
# 1  angry_actor_109.jpg                 0            31            157
# 2  angry_actor_120.jpg                 1            53             53
# 3   angry_actor_13.jpg                 0            77             51
# 4  angry_actor_132.jpg                 0            95             31
#
#    face_box_right  face_box_bottom  face_box_confidence  expression_label
# 0             226              141              22.9362                 0
# 1             345              219              50.3056                 0
# 2             372              372              13.9434                 2
# 3             362              388              85.8104                 3
# 4             412              476              82.3948                 0

# %%
df_info.shape
# Out:
# (91793, 8)

# %%
df_sel=df_info[df_info.face_box_confidence>40]
print(df_sel)
# Out:
#                            image_name  face_id_in_image  face_box_top  \
# 1                 angry_actor_109.jpg                 0            31
# 3                  angry_actor_13.jpg                 0            77
# 4                 angry_actor_132.jpg                 0            95
# 5                 angry_actor_137.jpg                 0            93
# 9                 angry_actor_150.jpg                 0            56
# ...                               ...               ...           ...
# 91786    surprised_expression_409.jpg                 0            80
# 91787  expressionless_husband_673.jpg                 0            48
# 91789    surprised_expression_381.jpg                 0            51
# 91790    surprised_expression_395.jpg                 0            27
# 91792    surprised_expression_394.jpg                 0            47
#
#        face_box_left  face_box_right  face_box_bottom  face_box_confidence  \
# ...

# %%
import os
img_path="/content/drive/MyDrive/DSAI PROJECT/origin"
for i, row in df_sel.iterrows():
  img_name=row["image_name"]
  com_file=os.path.join(img_path, img_name)
  files=cv2.imread(img_name)
  if files is not None:
    x1=row["face_box_left"]
    y1=row["face_box_right"]
    x2=row["face_box_bottom"]
    y2=row["face_box_top"]
    label=row["expression_label"]
    crop_images = files[x1:x2, y1:y2]
  else:
    print(f"error images, {img_name}")
# Out:
# Streaming output truncated to the last 5000 lines.
# error images, amazed_boss_362.jpg
# error images, amazed_boy_521.jpg
# error images, amazed_boss_314.jpg
# error images, amazed_chinese_210.jpg
# error images, amazed_boy_744.jpg
# error images, amazed_boss_373.jpg
# error images, amazed_chinese_52.jpg
# error images, amazed_chinese_251.jpg
# error images, amazed_chinese_12.jpg
# error images, amazed_black_445.jpg
# error images, amazed_boss_138.jpg
# error images, ecstatic_worker_120.jpg
# error images, amazed_chinese_563.jpg
# error images, amazed_chinese_563.jpg
# error images, amazed_boy_750.jpg
# error images, amazed_chinese_431.jpg
# error images, amazed_boss_110.jpg
# error images, amazed_chinese_480.jpg
# error images, amazed_chinese_499.jpg
# error images, amazed_chinese_251.jpg
# error images, amazed_boy_658.jpg
# error images, amazed_boss_353.jpg
# error images, amazed_boss_624.jpg
# error images, amazed_boy_210.jpg
# error images, amazed_boy_21.jpg
# ...

# %%
preprocessed_image=[]
labels=[]
def preprocessed_image(image_path,x1,y1, x2, y2):
  image=cv2.imread(os.path.join(label_file_path, image_file_name))
  terget_size=(224,224)
  image=cv2.resize(image,target_size)
  lit=row[y1:y2, x1:x2]
  return lit
  preprocessed_image.append(lit)
  labels.append(label)
image_path="/content/drive/MyDrive/DSAI PROJECT/data/image"
